# %% [markdown]
# <h1>Problem 2</h1>

# %%
import pandas as pd

# %%
data = pd.read_csv("adult.data.csv")

# %%
data
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.describe()
# Out:
#                 age        fnlwgt   education-num   capital-gain  \
# count  32561.000000  3.256100e+04    32561.000000   32561.000000
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32561.000000     32561.000000
# mean       87.303830        40.437456
# std       402.960219        12.347429
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1    workclass       32561 non-null  object
#  2    fnlwgt          32561 non-null  int64
#  3    education       32561 non-null  object
#  4    education-num   32561 non-null  int64
#  5    marital-status  32561 non-null  object
#  6    occupation      32561 non-null  object
#  7    relationship    32561 non-null  object
#  8    race            32561 non-null  object
#  9    sex             32561 non-null  object
#  10   capital-gain    32561 non-null  int64
#  11   capital-loss    32561 non-null  int64
#  12   hours-per-week  32561 non-null  int64
#  13   native-country  32561 non-null  object
#  14   salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' salary'],
#       dtype='object')

# %%
data[" sex"]
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3           Male
# 4         Female
#           ...
# 32556     Female
# 32557       Male
# 32558     Female
# 32559       Male
# 32560     Female
# Name:  sex, Length: 32561, dtype: object

# %%
data[data[" sex"]==' Female']
# Out:
#        age      workclass   fnlwgt      education   education-num  \
# 4       28        Private   338409      Bachelors              13
# 5       37        Private   284582        Masters              14
# 6       49        Private   160187            9th               5
# 8       31        Private    45781        Masters              14
# 12      23        Private   122272      Bachelors              13
# ...    ...            ...      ...            ...             ...
# 32546   37        Private   198216     Assoc-acdm              12
# 32549   43      State-gov   255835   Some-college              10
# 32556   27        Private   257302     Assoc-acdm              12
# 32558   58        Private   151910        HS-grad               9
# 32560   52   Self-emp-inc   287927        HS-grad               9
#
#                marital-status        occupation     relationship    race  \
# 4          Married-civ-spouse    Prof-specialty             Wife   Black
# ...

# %%
data[data[" sex"]==' Female']["age"].mean()
# Out:
# 36.85823043357163

# %%
data[data[" native-country"]==' Germany']
# Out:
#        age          workclass   fnlwgt      education   education-num  \
# 122     30            Private    77143      Bachelors              13
# 280     22            Private    34918      Bachelors              13
# 767     22            Private   151790   Some-college              10
# 1009    26            Private   109186   Some-college              10
# 1142    59        Federal-gov   212448        HS-grad               9
# ...    ...                ...      ...            ...             ...
# 32074   30            Private   318749      Assoc-voc              11
# 32101   45            Private   174794      Bachelors              13
# 32141   34            Private   193344   Some-college              10
# 32236   26            Private   323044   Some-college              10
# 32341   74   Self-emp-not-inc   199136      Bachelors              13
#
#             marital-status        occupation    relationship    race      sex  \
# ...

# %%
data[data[" salary"]==' >50K']['age'].mean()
# Out:
# 44.24984058155847

# %%
data[data[" salary"]==' >50K']['age'].std()
# Out:
# 10.519027719851826

# %%
data[data[" salary"]==' <=50K']['age'].mean()
# Out:
# 36.78373786407767

# %%
data[data[" salary"]==' <=50K']['age'].std()
# Out:
# 14.02008849082488

# %%
data[data[" salary"]==' >50K'][' education'].describe()
# Out:
# count           7841
# unique            15
# top        Bachelors
# freq            2221
# Name:  education, dtype: object

# %%
data[data[" salary"]==' >50K'][' education'].value_counts()
# Out:
#  Bachelors       2221
#  HS-grad         1675
#  Some-college    1387
#  Masters          959
#  Prof-school      423
#  Assoc-voc        361
#  Doctorate        306
#  Assoc-acdm       265
#  10th              62
#  11th              60
#  7th-8th           40
#  12th              33
#  9th               27
#  5th-6th           16
#  1st-4th            6
# Name:  education, dtype: int64

# %%
data.groupby(by=" race").describe()
# Out:
#                          age                                                \
#                        count       mean        std   min   25%   50%   75%
#  race
#  Amer-Indian-Eskimo    311.0  37.173633  12.447130  17.0  28.0  35.0  45.5
#  Asian-Pac-Islander   1039.0  37.746872  12.825133  17.0  28.0  36.0  45.0
#  Black                3124.0  37.767926  12.759290  17.0  28.0  36.0  46.0
#  Other                 271.0  33.457565  11.538865  17.0  25.0  31.0  41.0
#  White               27816.0  38.769881  13.782306  17.0  28.0  37.0  48.0
#
#                             fnlwgt                 ...  capital-loss          \
#                       max    count           mean  ...           75%     max
#  race                                              ...
#  Amer-Indian-Eskimo  82.0    311.0  120831.147910  ...           0.0  1980.0
#  Asian-Pac-Islander  90.0   1039.0  159940.609240  ...           0.0  2457.0
# ...

# %%
data[data[" sex"]==' Female']['age']
# Out:
# 4        28
# 5        37
# 6        49
# 8        31
# 12       23
#          ..
# 32546    37
# 32549    43
# 32556    27
# 32558    58
# 32560    52
# Name: age, Length: 10771, dtype: int64

# %%
race_age = data.groupby([" race","age"])

# %%
race_age.describe()
# Out:
#                          fnlwgt                                          \
#                           count           mean            std       min
#  race               age
#  Amer-Indian-Eskimo 17      3.0   85667.333333   52726.233000   27415.0
#                     18      4.0  147675.500000  124316.647074   40829.0
#                     19      6.0   82268.333333   87982.956676   29083.0
#                     20      3.0   66616.666667   61632.489730   27337.0
#                     21      6.0  181713.000000   91018.186890   75763.0
# ...                         ...            ...            ...       ...
#  White              85      3.0  126667.333333   35100.616410   98611.0
#                     86      1.0  149912.000000            NaN  149912.0
#                     87      1.0   90338.000000            NaN   90338.0
#                     88      3.0  153975.666667   74610.122754   68539.0
#                     90     34.0  175389.970588   92386.046987   39824.0
#
# ...

# %%
sex_age = data.groupby([" sex","age"])

# %%
sex_age.describe()
# Out:
#              fnlwgt                                                     \
#               count           mean            std       min        25%
#  sex    age
#  Female 17    186.0  181288.779570  112099.513620   19752.0  111697.75
#         18    268.0  183959.567164  105423.115009   20057.0  118376.00
#         19    356.0  196778.148876  119591.851153   20469.0  115483.75
#         20    363.0  194101.666667  101669.139180   24395.0  123275.00
#         21    329.0  191559.820669  102404.565360   20728.0  123727.00
# ...             ...            ...            ...       ...        ...
#  Male   84      6.0  242253.666667  112298.139770  127184.0  159519.50
#         85      2.0  106987.500000   11846.159905   98611.0  102799.25
#         87      1.0   90338.000000            NaN   90338.0   90338.00
#         88      2.0  196694.000000   13572.207558  187097.0  191895.50
#         90     29.0  156938.862069   98815.529401   39824.0   52386.00
#
# ...

# %%
data[" hours-per-week"].max()
# Out:
# 99

# %%
data[data[" hours-per-week"]==data[" hours-per-week"].max()]
# Out:
#        age          workclass   fnlwgt      education   education-num  \
# 935     37            Private   176900        HS-grad               9
# 1172    25            Private   404616        Masters              14
# 1887    55   Self-emp-not-inc   184425   Some-college              10
# 3578    37       Self-emp-inc   382802      Doctorate              16
# 4086    50                  ?   174964           10th               6
# ...    ...                ...      ...            ...             ...
# 30992   40       Self-emp-inc   104235        Masters              14
# 31681   43            Private   266324        HS-grad               9
# 31699   43   Self-emp-not-inc   163108   Some-college              10
# 32469   58       Self-emp-inc   181974      Doctorate              16
# 32531   30                  ?    33811      Bachelors              13
#
#             marital-status        occupation    relationship  \
# 935     Married-civ-spouse      Craft-repair         Husband
# ...

# %%
data[(data[" hours-per-week"]==99) & (data[" salary"]==' >50K')]
# Out:
#        age          workclass   fnlwgt      education   education-num  \
# 935     37            Private   176900        HS-grad               9
# 1172    25            Private   404616        Masters              14
# 1887    55   Self-emp-not-inc   184425   Some-college              10
# 3578    37       Self-emp-inc   382802      Doctorate              16
# 4441    43       Self-emp-inc   286750    Prof-school              15
# 8393    50       Self-emp-inc   119099   Some-college              10
# 8796    39            Private    70995      Bachelors              13
# 10986   38            Private   111499        HS-grad               9
# 13558   38            Private   191103    Prof-school              15
# 13858   37            Private    51264      Doctorate              16
# 15460   37            Private   241174      Bachelors              13
# 16604   73   Self-emp-not-inc   102510        7th-8th               4
# ...

# %%
len(data[(data[" hours-per-week"]==99) & (data[" salary"]==' >50K')])/len(data)*100
# Out:
# 0.07677896870489236

# %%
country_salary = data.groupby([" native-country"," salary"," hours-per-week"])
country_salary.describe()
# Out:
#                                           age                                 \
#                                         count   mean        std   min    25%
#  native-country  salary  hours-per-week
#  ?               <=50K  1                 2.0  73.50  10.606602  66.0  69.75
#                         4                 1.0  61.00        NaN  61.0  61.00
#                         5                 2.0  36.50   6.363961  32.0  34.25
#                         7                 1.0  42.00        NaN  42.0  42.00
#                         10                4.0  39.75  26.107151  17.0  20.75
# ...                                       ...    ...        ...   ...    ...
#  Yugoslavia      <=50K  66                1.0  45.00        NaN  45.0  45.00
#                  >50K   40                3.0  47.00  16.643317  35.0  37.50
#                         52                1.0  29.00        NaN  29.0  29.00
#                         60                1.0  36.00        NaN  36.0  36.00
# ...

# %%
sal_country = data[(data[" salary"]==' >50K')].groupby([" native-country"])
sal_country[" hours-per-week"].mean()
# Out:
#  native-country
#  ?                     45.547945
#  Cambodia              40.000000
#  Canada                45.641026
#  China                 38.900000
#  Columbia              50.000000
#  Cuba                  42.440000
#  Dominican-Republic    47.000000
#  Ecuador               48.750000
#  El-Salvador           45.000000
#  England               44.533333
#  France                50.750000
#  Germany               44.977273
#  Greece                50.625000
#  Guatemala             36.666667
#  Haiti                 42.750000
#  Honduras              60.000000
#  Hong                  45.000000
#  Hungary               50.000000
#  India                 46.475000
#  Iran                  47.500000
#  Ireland               48.000000
#  Italy                 45.400000
#  Jamaica               41.100000
#  Japan                 47.958333
#  Laos                  40.000000
#  Mexico                46.575758
#  Nicaragua             37.500000
#  Peru                  40.000000
# ...

# %%
sal_country = data[(data[" salary"]==' <=50K')].groupby([" native-country"])
sal_country[" hours-per-week"].mean()
# Out:
#  native-country
#  ?                             40.164760
#  Cambodia                      41.416667
#  Canada                        37.914634
#  China                         37.381818
#  Columbia                      38.684211
#  Cuba                          37.985714
#  Dominican-Republic            42.338235
#  Ecuador                       38.041667
#  El-Salvador                   36.030928
#  England                       40.483333
#  France                        41.058824
#  Germany                       39.139785
#  Greece                        41.809524
#  Guatemala                     39.360656
#  Haiti                         36.325000
#  Holand-Netherlands            40.000000
#  Honduras                      34.333333
#  Hong                          39.142857
#  Hungary                       31.300000
#  India                         38.233333
#  Iran                          41.440000
#  Ireland                       40.947368
# ...
